# %%
# Imporing required Packages/Modules
import os
import tensorflow as tf
import datetime
import numpy as np # For array-related manipulations
import pandas as pd # For DataFrame-related operations 
import matplotlib.pyplot as plt # Useful for graph plotting
import seaborn as sns # Another easy graph module
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report # Will be used for model evaluation
from keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from keras.models import Sequential, load_model # Base class for most Neural Networks
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, TensorBoard, EarlyStopping
from sklearn.svm import SVC
from keras.layers import Input, Conv2D, MaxPool2D, Dense
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization, AveragePooling2D
from tensorflow.keras.layers import Concatenate, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, TensorBoard
import time

# %%
data_dir = r'D:\New_Fourth_Year\projectDesignGit\pestInfestationSeverityLevel\Sugarcane Leaf Disease Split No Background'

Train_Data_Generator = ImageDataGenerator(featurewise_center=False,
                                    rescale=1./255,
                                    #rotation_range=30,
                                    width_shift_range=0.2,
                                    height_shift_range=0.2,
                                    shear_range=0.2,
                                    zoom_range=0.2,
                                    horizontal_flip=True,)

Test_Data_Generator = ImageDataGenerator(
                                    rescale=1./255)

train_set = Train_Data_Generator.flow_from_directory(directory=data_dir + '/train',
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               batch_size=32,
                                               shuffle=True)


val_set = Test_Data_Generator.flow_from_directory(directory=data_dir + '/validation',
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               batch_size=32,
                                               shuffle=True)
# Out:
# Found 1845 images belonging to 5 classes.
# Found 465 images belonging to 5 classes.

# %%
import matplotlib.pyplot as plt

# Extract the images and labels from the batch
images, labels = next(train_set)

# Output the first five images
for i in range(5):
    # Display the current image and label using matplotlib
    plt.imshow(images[i])
    plt.title(f"Image {i + 1} - Label: {labels[i]}")
    plt.show()

# %%
import matplotlib.pyplot as plt

# Extract the images and labels from the batch
images, labels = next(val_set)

# Output the first five images
for i in range(5):
    # Display the current image and label using matplotlib
    plt.imshow(images[i])
    plt.title(f"Image {i + 1} - Label: {labels[i]}")
    plt.show()

# %%
import keras
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Dense, Input, Activation, Dropout, GlobalAveragePooling2D, \
    BatchNormalization, concatenate, AveragePooling2D



def conv_layer(conv_x, filters):
    conv_x = BatchNormalization()(conv_x)
    conv_x = Activation('relu')(conv_x)
    conv_x = Conv2D(filters, (3, 3), kernel_initializer='he_uniform', padding='same', use_bias=False)(conv_x)
    conv_x = Dropout(0.2)(conv_x)

    return conv_x


def dense_block(block_x, filters, growth_rate, layers_in_block):
    for i in range(layers_in_block):
        each_layer = conv_layer(block_x, growth_rate)
        block_x = concatenate([block_x, each_layer], axis=-1)
        filters += growth_rate

    return block_x, filters


def transition_block(trans_x, tran_filters):
    trans_x = BatchNormalization()(trans_x)
    trans_x = Activation('relu')(trans_x)
    trans_x = Conv2D(tran_filters, (1, 1), kernel_initializer='he_uniform', padding='same', use_bias=False)(trans_x)
    trans_x = AveragePooling2D((2, 2), strides=(2, 2))(trans_x)

    return trans_x, tran_filters


def dense_net(filters, growth_rate, classes, dense_block_size, layers_in_block):
    input_img = Input(shape=(224, 224, 3))
    x = Conv2D(12, (3, 3), kernel_initializer='he_uniform', padding='same', use_bias=False)(input_img)

    dense_x = BatchNormalization()(x)
    dense_x = Activation('relu')(x)

    dense_x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(dense_x)
    for block in range(dense_block_size - 1):
        dense_x, filters = dense_block(dense_x, filters, growth_rate, layers_in_block)
        dense_x, filters = transition_block(dense_x, filters)

    dense_x, filters = dense_block(dense_x, filters, growth_rate, layers_in_block)
    dense_x = BatchNormalization()(dense_x)
    dense_x = Activation('relu')(dense_x)
    dense_x = GlobalAveragePooling2D()(dense_x)

    output = Dense(classes, activation='softmax')(dense_x)

    return Model(input_img, output)

# %%
dense_block_size = 3
layers_in_block = 4

growth_rate = 4
classes = 5
model = dense_net(growth_rate * 2, growth_rate, classes, dense_block_size, layers_in_block)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 12  324         ['input_1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 224, 224, 12  0           ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 12  0           ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 112, 112, 12  48         ['max_pooling2d[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 112, 112, 12  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 112, 112, 4)  432         ['activation_1[0][0]']
#
#  dropout (Dropout)              (None, 112, 112, 4)  0           ['conv2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 112, 112, 16  0           ['max_pooling2d[0][0]',
#                                 )                                 'dropout[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 112, 112, 16  64         ['concatenate[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 112, 112, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 112, 112, 4)  576         ['activation_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 112, 112, 4)  0           ['conv2d_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 112, 112, 20  0           ['concatenate[0][0]',
#                                 )                                 'dropout_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 112, 112, 20  80         ['concatenate_1[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 112, 112, 20  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 4)  720         ['activation_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 112, 112, 4)  0           ['conv2d_3[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 112, 112, 24  0           ['concatenate_1[0][0]',
#                                 )                                 'dropout_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 112, 112, 24  96         ['concatenate_2[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 112, 112, 24  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 112, 112, 4)  864         ['activation_4[0][0]']
#
#  dropout_3 (Dropout)            (None, 112, 112, 4)  0           ['conv2d_4[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 112, 112, 28  0           ['concatenate_2[0][0]',
#                                 )                                 'dropout_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 112, 112, 28  112        ['concatenate_3[0][0]']
#  rmalization)                   )
#
#  activation_5 (Activation)      (None, 112, 112, 28  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 112, 112, 24  672         ['activation_5[0][0]']
#                                 )
#
#  average_pooling2d (AveragePool  (None, 56, 56, 24)  0           ['conv2d_5[0][0]']
#  ing2D)
#
#  batch_normalization_6 (BatchNo  (None, 56, 56, 24)  96          ['average_pooling2d[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 56, 56, 24)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 4)    864         ['activation_6[0][0]']
#
#  dropout_4 (Dropout)            (None, 56, 56, 4)    0           ['conv2d_6[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 56, 56, 28)   0           ['average_pooling2d[0][0]',
#                                                                   'dropout_4[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 28)  112         ['concatenate_4[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 56, 56, 28)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 4)    1008        ['activation_7[0][0]']
#
#  dropout_5 (Dropout)            (None, 56, 56, 4)    0           ['conv2d_7[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 56, 56, 32)   0           ['concatenate_4[0][0]',
#                                                                   'dropout_5[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 56, 56, 32)  128         ['concatenate_5[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 56, 56, 32)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 56, 56, 4)    1152        ['activation_8[0][0]']
#
#  dropout_6 (Dropout)            (None, 56, 56, 4)    0           ['conv2d_8[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 56, 56, 36)   0           ['concatenate_5[0][0]',
#                                                                   'dropout_6[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 56, 56, 36)  144         ['concatenate_6[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 56, 56, 36)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 56, 56, 4)    1296        ['activation_9[0][0]']
#
#  dropout_7 (Dropout)            (None, 56, 56, 4)    0           ['conv2d_9[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 56, 56, 40)   0           ['concatenate_6[0][0]',
#                                                                   'dropout_7[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 56, 56, 40)  160         ['concatenate_7[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 56, 56, 40)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 56, 56, 40)   1600        ['activation_10[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 28, 28, 40)  0           ['conv2d_10[0][0]']
#  oling2D)
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 40)  160         ['average_pooling2d_1[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 28, 28, 40)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 4)    1440        ['activation_11[0][0]']
#
#  dropout_8 (Dropout)            (None, 28, 28, 4)    0           ['conv2d_11[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 28, 28, 44)   0           ['average_pooling2d_1[0][0]',
#                                                                   'dropout_8[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 44)  176         ['concatenate_8[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 28, 28, 44)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 4)    1584        ['activation_12[0][0]']
#
#  dropout_9 (Dropout)            (None, 28, 28, 4)    0           ['conv2d_12[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 28, 28, 48)   0           ['concatenate_8[0][0]',
#                                                                   'dropout_9[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 48)  192         ['concatenate_9[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 28, 28, 48)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 4)    1728        ['activation_13[0][0]']
#
#  dropout_10 (Dropout)           (None, 28, 28, 4)    0           ['conv2d_13[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 28, 28, 52)   0           ['concatenate_9[0][0]',
#                                                                   'dropout_10[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 52)  208         ['concatenate_10[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 28, 28, 52)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 4)    1872        ['activation_14[0][0]']
#
#  dropout_11 (Dropout)           (None, 28, 28, 4)    0           ['conv2d_14[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 28, 28, 56)   0           ['concatenate_10[0][0]',
#                                                                   'dropout_11[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 56)  224         ['concatenate_11[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 28, 28, 56)   0           ['batch_normalization_15[0][0]']
#
#  global_average_pooling2d (Glob  (None, 56)          0           ['activation_15[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 5)            285         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 18,417
# Trainable params: 17,417
# Non-trainable params: 1,000
# __________________________________________________________________________________________________

# %%
# CALLBACKS
# %load_ext tensorboard
# reduce learning rate when val_accuracy has stopped improving
lr_reduce = ReduceLROnPlateau(monitor='val_loss',
                                          factor=0.6,
                                          patience=2,
                                          verbose=1,
                                          mode='max',
                                          min_lr=1e-7)
# stop training when val_accuracy has stopped improving
early_stop = EarlyStopping(monitor='val_loss',
                                       patience=5,
                                       verbose=1,
                                       mode='max')
# callback to save the Keras model and (best) weights obtained on an epoch basis. here, the trained (compiled) model is saved in the current working directory as 'cifar10.h5'
checkpoint = ModelCheckpoint(f'DenseNet-{datetime.datetime.now().__format__("%Y-%m-%d-%H-%M-%S")}.h5',
                                         monitor='val_loss',
                                         verbose=1,
                                         save_weights_only=False,
                                         save_best_only=True,
                                         mode='max',
                                         save_freq='epoch')

#Tensorboard
current_time = datetime.datetime.now().__format__('%Y-%m-%d-%H-%M-%S')
tb_callback = TensorBoard(log_dir=f"./logs/DenseNet-{current_time}", histogram_freq=2)

# %%
# Record the start time
start_time = time.time()

# Your existing code for model compilation and training
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

train_history = model.fit(
    train_set,
    batch_size=4,
    validation_data = val_set,
    # steps_per_epoch = EPOCH_STEPS,
    epochs=30,
    verbose =1,
    
    callbacks=[lr_reduce, checkpoint, tb_callback, early_stop]
)

# Record the end time
end_time = time.time()

# Calculate and print the total training time
total_time = end_time - start_time
print(f"Total training time: {total_time:.2f} seconds")
# Out:
# Epoch 1/30
# 58/58 [==============================] - ETA: 0s - loss: 1.4169 - accuracy: 0.4087
# Epoch 1: val_loss improved from -inf to 1.53641, saving model to DenseNet-2024-01-07-14-37-25.h5
# 58/58 [==============================] - 24s 326ms/step - loss: 1.4169 - accuracy: 0.4087 - val_loss: 1.5364 - val_accuracy: 0.3527 - lr: 0.0010
# Epoch 2/30
# 58/58 [==============================] - ETA: 0s - loss: 1.2003 - accuracy: 0.5501
# Epoch 2: val_loss improved from 1.53641 to 1.63779, saving model to DenseNet-2024-01-07-14-37-25.h5
# 58/58 [==============================] - 18s 304ms/step - loss: 1.2003 - accuracy: 0.5501 - val_loss: 1.6378 - val_accuracy: 0.2688 - lr: 0.0010
# Epoch 3/30
# 58/58 [==============================] - ETA: 0s - loss: 1.0958 - accuracy: 0.5859
# Epoch 3: val_loss improved from 1.63779 to 1.69299, saving model to DenseNet-2024-01-07-14-37-25.h5
# 58/58 [==============================] - 18s 304ms/step - loss: 1.0958 - accuracy: 0.5859 - val_loss: 1.6930 - val_accuracy: 0.3097 - lr: 0.0010
# Epoch 4/30
# 58/58 [==============================] - ETA: 0s - loss: 1.0416 - accuracy: 0.6119
# Epoch 4: val_loss did not improve from 1.69299
# 58/58 [==============================] - 18s 301ms/step - loss: 1.0416 - accuracy: 0.6119 - val_loss: 1.4215 - val_accuracy: 0.4043 - lr: 0.0010
# Epoch 5/30
# 58/58 [==============================] - ETA: 0s - loss: 0.9773 - accuracy: 0.6379
# Epoch 5: val_loss improved from 1.69299 to 1.88891, saving model to DenseNet-2024-01-07-14-37-25.h5
# 58/58 [==============================] - 18s 301ms/step - loss: 0.9773 - accuracy: 0.6379 - val_loss: 1.8889 - val_accuracy: 0.3484 - lr: 0.0010
# Epoch 6/30
# 58/58 [==============================] - ETA: 0s - loss: 0.9661 - accuracy: 0.6379
# Epoch 6: val_loss improved from 1.88891 to 2.21111, saving model to DenseNet-2024-01-07-14-37-25.h5
# 58/58 [==============================] - 17s 299ms/step - loss: 0.9661 - accuracy: 0.6379 - val_loss: 2.2111 - val_accuracy: 0.3462 - lr: 0.0010
# Epoch 7/30
# 58/58 [==============================] - ETA: 0s - loss: 0.9298 - accuracy: 0.6558
# Epoch 7: val_loss did not improve from 2.21111
# 58/58 [==============================] - 17s 301ms/step - loss: 0.9298 - accuracy: 0.6558 - val_loss: 1.4921 - val_accuracy: 0.4817 - lr: 0.0010
# Epoch 8/30
# 58/58 [==============================] - ETA: 0s - loss: 0.8955 - accuracy: 0.6688
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
#
# Epoch 8: val_loss did not improve from 2.21111
# 58/58 [==============================] - 17s 299ms/step - loss: 0.8955 - accuracy: 0.6688 - val_loss: 1.9180 - val_accuracy: 0.4215 - lr: 0.0010
# Epoch 9/30
# 58/58 [==============================] - ETA: 0s - loss: 0.8789 - accuracy: 0.6699
# Epoch 9: val_loss did not improve from 2.21111
# 58/58 [==============================] - 17s 298ms/step - loss: 0.8789 - accuracy: 0.6699 - val_loss: 1.5555 - val_accuracy: 0.4495 - lr: 6.0000e-04
# Epoch 10/30
# 58/58 [==============================] - ETA: 0s - loss: 0.8606 - accuracy: 0.6786
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
#
# Epoch 10: val_loss did not improve from 2.21111
# 58/58 [==============================] - 17s 297ms/step - loss: 0.8606 - accuracy: 0.6786 - val_loss: 1.2812 - val_accuracy: 0.5247 - lr: 6.0000e-04
# Epoch 11/30
# 58/58 [==============================] - ETA: 0s - loss: 0.8383 - accuracy: 0.6954
# Epoch 11: val_loss did not improve from 2.21111
# 58/58 [==============================] - 17s 299ms/step - loss: 0.8383 - accuracy: 0.6954 - val_loss: 1.4766 - val_accuracy: 0.4624 - lr: 3.6000e-04
# Epoch 11: early stopping
# Total training time: 198.73 seconds

# %%
import matplotlib.pyplot as plt

# Assuming you have the training history stored in the variable 'train_history'

# Plot the training loss
plt.plot(train_history.history['loss'], label='Training Loss')

# Plot the validation loss
plt.plot(train_history.history['val_loss'], label='Validation Loss')

plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have the training history stored in the variable 'train_history'

# Plot the training accuracy
plt.plot(train_history.history['accuracy'], label='Training Accuracy')

# Plot the validation accuracy
plt.plot(train_history.history['val_accuracy'], label='Validation Accuracy')

plt.title('Training and Validation Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have the true labels and predicted labels for the test set
true_labels = test_set.classes

# Ensure that model.predict returns a NumPy array
predicted_probs = model.predict(test_set)
if isinstance(predicted_probs, list):
    # Concatenate the predictions from multiple branches (assuming main branch is the first)
    predicted_probs = np.concatenate(predicted_probs, axis=1)

# Convert predicted probabilities to class indices
predicted_labels = predicted_probs.argmax(axis=1)

# Compute confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       4 import numpy as np
#       6 # Assuming you have the true labels and predicted labels for the test set
# ----> 7 true_labels = test_set.classes
#       9 # Ensure that model.predict returns a NumPy array
#      10 predicted_probs = model.predict(test_set)
#
# NameError: name 'test_set' is not defined

# %%
import matplotlib.pyplot as plt

# Display the first image in the batch
plt.imshow(images[0])
plt.show()

# %% [markdown]
# # Constraints

# %%
# Extract a batch of images from your dataset
images, _ = next(val_set)

# Measure inference time for making predictions
start_time = time.time()

# Assuming your model is named 'model' and you want predictions for the batch of images
predictions = model.predict(images)

end_time = time.time()

# Calculate and print the inference time
inference_time = end_time - start_time
print(f"Inference Time: {inference_time:.4f} seconds")
# Out:
# Inference Time: 0.2181 seconds

# %%
def get_model_size(model):
    # Save the model to a temporary file
    model.save('temp_model.h5')

    # Get the size of the saved model file
    model_size = os.path.getsize('temp_model.h5')

    # Remove the temporary file
    os.remove('temp_model.h5')

    return model_size

# Load your model
model = tf.keras.models.load_model(r'D:\New_Fourth_Year\projectDesignGit\sugarcaneSeverityLevel\DenseNet-2024-01-07-14-37-25.h5')

# Get the size of the model
model_size_bytes = get_model_size(model)

# Convert bytes to megabytes for better readability
model_size_megabytes = model_size_bytes / (1024 * 1024)

print(f"Model Size: {model_size_megabytes:.2f} MB")
# Out:
# Model Size: 0.50 MB

# %%
model = tf.keras.models.load_model(r'D:\New_Fourth_Year\projectDesignGit\sugarcaneSeverityLevel\DenseNet-2024-01-07-14-37-25.h5')
# Assuming you have a test set generator
test_set = val_set  # Define or load your test set generator

# Use model.evaluate to get accuracy and other metrics
results = model.evaluate(test_set, verbose=1)  # Set verbose=1 for more information

# 'results' is a list containing the evaluation metrics
accuracy = results[1]  # Index 1 corresponds to the accuracy

# Compute misclassification rate
misclassification_rate = 1 - accuracy

print(f'Misclassification Rate: {misclassification_rate * 100:.2f}%')
# Out:
# 15/15 [==============================] - 2s 128ms/step - loss: 2.2111 - accuracy: 0.3462
# Misclassification Rate: 65.38%

# %%
# 'results' is a list containing the evaluation metrics
main_accuracy = results[4]  # Index 4 corresponds to the accuracy of the main branch

print(f'Main Branch Accuracy: {main_accuracy:.2%}')
# Out:
# Main Branch Accuracy: 34.41%

# %%
from sklearn.metrics import accuracy_score

# Assuming you have the true labels and predicted labels for the test set
true_labels = test_set.classes

# Ensure that model.predict returns a NumPy array
predicted_probs = model.predict(test_set)
if isinstance(predicted_probs, list):
    # Concatenate the predictions from multiple branches (assuming main branch is the first)
    predicted_probs = np.concatenate(predicted_probs, axis=1)

# Convert predicted probabilities to class labels
predicted_labels = predicted_probs.argmax(axis=1)

# Compute accuracy using sklearn's accuracy_score
accuracy = accuracy_score(true_labels, predicted_labels)

# Compute misclassification rate
misclassification_rate = 1 - accuracy

print(f'Misclassification Rate: {misclassification_rate:.2%}')
# Out:
# 170/170 [==============================] - 6s 33ms/step
# Misclassification Rate: 96.31%

# %%
def get_flops(model_h5_path):
    session = tf.compat.v1.Session()
    graph = tf.compat.v1.get_default_graph()


    with graph.as_default():
        with session.as_default():
            model = tf.keras.models.load_model(model_h5_path)

            run_meta = tf.compat.v1.RunMetadata()
            opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()

            # We use the Keras session graph in the call to the profiler.
            flops = tf.compat.v1.profiler.profile(graph=graph,
                                                  run_meta=run_meta, cmd='op', options=opts)

            return flops.total_float_ops

# %%
model_h5_path = r'D:\New_Fourth_Year\projectDesignGit\sugarcaneSeverityLevel\DenseNet-2024-01-07-14-37-25.h5'
# Get and print the FLOPs
flops = get_flops(model_h5_path)
print(f"Number of FLOPs: {flops}")
# Out:
# WARNING:tensorflow:From c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras\layers\normalization\batch_normalization.py:532: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\profiler\internal\flops_registry.py:138: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# Number of FLOPs: 18462
