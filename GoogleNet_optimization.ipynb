# %%
# Imporing required Packages/Modules
import os
import tensorflow as tf
import datetime
import numpy as np # For array-related manipulations
import pandas as pd # For DataFrame-related operations 
import matplotlib.pyplot as plt # Useful for graph plotting
import seaborn as sns # Another easy graph module
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report # Will be used for model evaluation
from keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from keras.models import Sequential, load_model # Base class for most Neural Networks
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, TensorBoard, EarlyStopping
from sklearn.svm import SVC
from keras.layers import Input, Conv2D, MaxPool2D, Dense
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization, AveragePooling2D
from tensorflow.keras.layers import Concatenate, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, TensorBoard
import time

# %%
data_dir = r'D:\New_Fourth_Year\projectDesignGit\pestInfestationSeverityLevel\Sugarcane Leaf Disease Split No Background'

Train_Data_Generator = ImageDataGenerator(featurewise_center=False,
                                    rescale=1./255,
                                    #rotation_range=30,
                                    width_shift_range=0.2,
                                    height_shift_range=0.2,
                                    shear_range=0.2,
                                    zoom_range=0.2,
                                    horizontal_flip=True,)

Test_Data_Generator = ImageDataGenerator(
                                    rescale=1./255)

train_set = Train_Data_Generator.flow_from_directory(directory=data_dir + '/train',
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               batch_size=32,
                                               shuffle=True)


val_set = Test_Data_Generator.flow_from_directory(directory=data_dir + '/validation',
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               batch_size=32,
                                               shuffle=True)
# Out:
# Found 1845 images belonging to 5 classes.
# Found 465 images belonging to 5 classes.

# %%
import matplotlib.pyplot as plt

# Extract the images and labels from the batch
images, labels = next(train_set)

# Output the first five images
for i in range(5):
    # Display the current image and label using matplotlib
    plt.imshow(images[i])
    plt.title(f"Image {i + 1} - Label: {labels[i]}")
    plt.show()

# %%
import matplotlib.pyplot as plt

# Extract the images and labels from the batch
images, labels = next(val_set)

# Output the first five images
for i in range(5):
    # Display the current image and label using matplotlib
    plt.imshow(images[i])
    plt.title(f"Image {i + 1} - Label: {labels[i]}")
    plt.show()

# %%
IMAGE_SHAPE = (224, 224, 3)
CLASS_NUM = 5
# create model
def inception(x, filters):
    # 1x1C
    path1 = Conv2D(filters=filters[0], kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)

    # 1x1->3x3
    path2 = Conv2D(filters=filters[1][0], kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)
    path2 = Conv2D(filters=filters[1][1], kernel_size=(3,3), strides=1, padding='same', activation='relu')(path2)
    
    # 1x1->5x5
    path3 = Conv2D(filters=filters[2][0], kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)
    path3 = Conv2D(filters=filters[2][1], kernel_size=(5,5), strides=1, padding='same', activation='relu')(path3)

    # 3x3->1x1
    path4 = MaxPooling2D(pool_size=(3,3), strides=1, padding='same')(x)
    path4 = Conv2D(filters=filters[3], kernel_size=(1,1), strides=1, padding='same', activation='relu')(path4)

    return Concatenate(axis=-1)([path1,path2,path3,path4])


def auxiliary(x, name=None):
    layer = AveragePooling2D(pool_size=(5,5), strides=3, padding='valid')(x)
    layer = Conv2D(filters=128, kernel_size=(1,1), strides=1, padding='same', activation='relu')(layer)
    layer = Flatten()(layer)
    layer = Dense(units=256, activation='relu')(layer)
    layer = Dropout(0.4)(layer)
    layer = Dense(units=CLASS_NUM, activation='softmax', name=name)(layer)
    return layer


def googlenet(hp):
    layer_in = Input(shape=IMAGE_SHAPE)
    
    # stage-1
    filters_stage1 = hp.Choice('filters_stage1', values=[32, 64, 128], default=64)
    layer = Conv2D(filters=filters_stage1, kernel_size=(7,7), strides=2, padding='same', activation='relu')(layer_in)
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)
    layer = BatchNormalization()(layer)

    # stage-2
    filters_stage2 = hp.Choice('filters_stage2', values=[32, 64, 128], default=64)
    layer = Conv2D(filters=filters_stage2, kernel_size=(1,1), strides=1, padding='same', activation='relu')(layer)
    layer = Conv2D(filters=filters_stage2, kernel_size=(3,3), strides=1, padding='same', activation='relu')(layer)
    layer = BatchNormalization()(layer)
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)

    # stage-3
    filters_stage3 = hp.Choice('filters_stage3', values=[32, 64, 128], default=64)
    layer = inception(layer, [filters_stage3,  (96,128), (16,32), 32]) #3a
    layer = inception(layer, [filters_stage3, (128,192), (32,96), 64]) #3b
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)
    
    # stage-4
    layer = inception(layer, [192,  (96,208),  (16,48),  64]) #4a
    aux1  = auxiliary(layer, name='aux1')
    layer = inception(layer, [160, (112,224),  (24,64),  64]) #4b
    layer = inception(layer, [128, (128,256),  (24,64),  64]) #4c
    layer = inception(layer, [112, (144,288),  (32,64),  64]) #4d
    aux2  = auxiliary(layer, name='aux2')
    layer = inception(layer, [256, (160,320), (32,128), 128]) #4e
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)
    
    # stage-5
    layer = inception(layer, [256, (160,320), (32,128), 128]) #5a
    layer = inception(layer, [384, (192,384), (48,128), 128]) #5b
    layer = AveragePooling2D(pool_size=(7,7), strides=1, padding='valid')(layer)
    
    # stage-6
    droputStage6 = hp.Choice('droputStage6', values=[0.2, 0.4, 0.6], default=0.4)
    layer = Flatten()(layer)
    layer = Dropout(droputStage6)(layer)
    layer = Dense(units=256, activation='linear')(layer)
    main = Dense(units=CLASS_NUM, activation='softmax', name='main')(layer)
    
    model = Model(inputs=layer_in, outputs=[main, aux1, aux2])
    
    # Specify the learning rate as a hyperparameter
    lr = hp.Choice('learning_rate', values=[1e-4, 1e-3, 1e-2], default=1e-3)

    # Create the optimizer with the chosen learning rate
    optimizer = Adam(learning_rate=lr)

    # Compile the model
    model.compile(
        loss='categorical_crossentropy',
        optimizer=optimizer,
        metrics=['accuracy']
    )

    return model

# # train model
# model = googlenet()
# model.summary()
#model.load_weights(MODEL_NAME)
#tf.keras.utils.plot_model(model, 'GoogLeNet.png')

#optimizer = Adam(lr=2 * 1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
#optimizer = SGD(lr=1 * 1e-1, momentum=0.9, nesterov=True)
#model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
#model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from kerastuner.tuners import BayesianOptimization
from kerastuner.engine.hyperparameters import HyperParameters
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization, AveragePooling2D, Flatten, Dense, Dropout, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical

# Define the Bayesian Optimization tuner
tunerA = BayesianOptimization(
    googlenet,
    objective='val_loss',
    max_trials=100,  # You can adjust this based on your requirements
    num_initial_points=5,  # Number of initial random trials
    hyperparameters=HyperParameters(),
    directory='my_dir',
    project_name='design_a'
)

# Early stopping callback
stop_early = EarlyStopping(monitor='val_loss', patience=5)

# Start the search for the best hyperparameters
tunerA.search(train_set, epochs=100, validation_data=val_set, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hpsA = tunerA.oracle.get_best_trials(num_trials=1)[0].hyperparameters.values

# Build the model with the best hyperparameters
modelA = googlenet(best_hpsA)
modelA.summary()

# Print the best hyperparameters
print(best_hpsA)
# Out:
# Trial 14 Complete [00h 05m 49s]
# val_loss: 1.8564069271087646
#
# Best val_loss So Far: 1.5294151306152344
# Total elapsed time: 01h 22m 42s
#
# Search: Running Trial #15
#
# Value             |Best Value So Far |Hyperparameter
# 128               |128               |filters_stage1
# 128               |128               |filters_stage2
# 64                |128               |filters_stage3
# 0.6               |0.6               |droputStage6
# 0.0001            |0.001             |learning_rate
#
# Epoch 1/100
#  5/58 [=>............................] - ETA: 17s - loss: 5.2518 - main_loss: 1.6937 - aux1_loss: 1.9221 - aux2_loss: 1.6361 - main_accuracy: 0.1562 - aux1_accuracy: 0.1813 - aux2_accuracy: 0.1688
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 26
#      23 stop_early = EarlyStopping(monitor='val_loss', patience=5)
#      25 # Start the search for the best hyperparameters
# ---> 26 tunerA.search(train_set, epochs=100, validation_data=val_set, callbacks=[stop_early])
#      28 # Get the optimal hyperparameters
#      29 best_hpsA = tunerA.oracle.get_best_trials(num_trials=1)[0].hyperparameters.values
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras_tuner\src\engine\base_tuner.py:233, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     230         continue
#     232     self.on_trial_begin(trial)
# --> 233     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     234     self.on_trial_end(trial)
#     235 self.on_search_end()
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras_tuner\src\engine\base_tuner.py:273, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     271 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     272     try:
# --> 273         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     274         trial.status = trial_module.TrialStatus.COMPLETED
#     275         return
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras_tuner\src\engine\base_tuner.py:238, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     237 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 238     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     239     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     240         self.oracle.objective.name
#     241     ):
#     242         # The oracle is updated by calling `self.oracle.update_trial()` in
#     243         # `Tuner.run_trial()`. For backward compatibility, we support this
#     244         # use case. No further action needed in this case.
#     245         warnings.warn(
#     246             "The use case of calling "
#     247             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     253             stacklevel=2,
#     254         )
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras_tuner\src\engine\tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras_tuner\src\engine\tuner.py:233, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     231 hp = trial.hyperparameters
#     232 model = self._try_build(hp)
# --> 233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#     236 if backend.config.multi_backend():
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras_tuner\src\engine\hypermodel.py:149, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     125 def fit(self, hp, model, *args, **kwargs):
#     126     """Train the model.
#     127
#     128     Args:
#    (...)
#     147         If return a float, it should be the `objective` value.
#     148     """
# --> 149     return model.fit(*args, **kwargs)
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras\engine\training.py:1389, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387 logs = tmp_logs  # No error, now safe to assign to logs.
#    1388 end_step = step + data_handler.step_increment
# -> 1389 callbacks.on_train_batch_end(end_step, logs)
#    1390 if self.stop_training:
#    1391   break
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py:438, in CallbackList.on_train_batch_end(self, batch, logs)
#     431 """Calls the `on_train_batch_end` methods of its callbacks.
#     432
#     433 Args:
#     434     batch: Integer, index of batch within the current epoch.
#     435     logs: Dict. Aggregated metric results up until this batch.
#     436 """
#     437 if self._should_call_train_batch_hooks:
# --> 438   self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py:297, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     295   self._call_batch_begin_hook(mode, batch, logs)
#     296 elif hook == 'end':
# --> 297   self._call_batch_end_hook(mode, batch, logs)
#     298 else:
#     299   raise ValueError(
#     300       f'Unrecognized hook: {hook}. Expected values are ["begin", "end"]')
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py:318, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     315   batch_time = time.time() - self._batch_start_time
#     316   self._batch_times.append(batch_time)
# --> 318 self._call_batch_hook_helper(hook_name, batch, logs)
#     320 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     321   end_hook_name = hook_name
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py:353, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     350 if self._check_timing:
#     351   start_time = time.time()
# --> 353 logs = self._process_logs(logs, is_batch_hook=True)
#     354 for callback in self.callbacks:
#     355   hook = getattr(callback, hook_name)
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras\callbacks.py:272, in CallbackList._process_logs(self, logs, is_batch_hook)
#     270 if is_batch_hook and self._batch_hooks_support_tf_logs:
#     271   return logs
# --> 272 return tf_utils.sync_to_numpy_or_python_type(logs)
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras\utils\tf_utils.py:563, in sync_to_numpy_or_python_type(tensors)
#     560     return t
#     561   return t.item() if np.ndim(t) == 0 else t
# --> 563 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\util\nest.py:914, in map_structure(func, *structure, **kwargs)
#     910 flat_structure = (flatten(s, expand_composites) for s in structure)
#     911 entries = zip(*flat_structure)
#     913 return pack_sequence_as(
# --> 914     structure[0], [func(*x) for x in entries],
#     915     expand_composites=expand_composites)
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\util\nest.py:914, in <listcomp>(.0)
#     910 flat_structure = (flatten(s, expand_composites) for s in structure)
#     911 entries = zip(*flat_structure)
#     913 return pack_sequence_as(
# --> 914     structure[0], [func(*x) for x in entries],
#     915     expand_composites=expand_composites)
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras\utils\tf_utils.py:557, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     554 def _to_single_numpy_or_python_type(t):
#     555   # Don't turn ragged or sparse tensors to NumPy.
#     556   if isinstance(t, tf.Tensor):
# --> 557     t = t.numpy()
#     558   # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559   if not isinstance(t, (np.ndarray, np.generic)):
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\ops.py:1223, in _EagerTensorBase.numpy(self)
#    1200 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1201
#    1202 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1220     NumPy dtype.
#    1221 """
#    1222 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\ops.py:1189, in _EagerTensorBase._numpy(self)
#    1187 def _numpy(self):
#    1188   try:
# -> 1189     return self._numpy_internal()
#    1190   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
# optimizer = ['Adam', 'SGD', 'Adam', 'SGD']
# epochs = [20, 30, 20, 30]
# history_all = {}

# for i in range(len(optimizer)):
#     print('Usnig optimizer: ' + optimizer[i] + ', Epoch: ' + str(epochs[i]))
    
#     model.compile(loss='categorical_crossentropy', 
#                   loss_weights={'main': 1.0, 'aux1': 0.3, 'aux2': 0.3},
#                   optimizer=optimizer[i], metrics=['accuracy'])
    
#     train_history = model.fit_generator(
#             train_generator,
#             steps_per_epoch=EPOCH_STEPS,
#             epochs=epochs[i],
#             #callbacks=[checkpoint]
#             shuffle=True
#             )
    
#     # save history    
#     if len(history_all) == 0:
#         history_all = {key: [] for key in train_history.history}
    
#     for key in history_all:
#         history_all[key].extend(train_history.history[key])

# model.save(MODEL_NAME)

# # show train history
# def show_train_history(history, xlabel, ylabel, train):
#     for item in train:
#         plt.plot(history[item])
#     plt.title('Train History')
#     plt.xlabel(xlabel)
#     plt.ylabel(ylabel)
#     plt.legend(train, loc='upper left')
#     plt.show()

# show_train_history(history_all, 'Epoch', 'Accuracy', ('main_acc', 'aux1_acc', 'aux2_acc'))
# show_train_history(history_all, 'Epoch', 'Loss', ('main_loss', 'aux1_loss', 'aux2_loss'))

# %%
# CALLBACKS
# %load_ext tensorboard
# reduce learning rate when val_accuracy has stopped improving
lr_reduce = ReduceLROnPlateau(monitor='val_loss',
                                          factor=0.6,
                                          patience=2,
                                          verbose=1,
                                          mode='max',
                                          min_lr=1e-7)
# stop training when val_accuracy has stopped improving
early_stop = EarlyStopping(monitor='val_loss',
                                       patience=5,
                                       verbose=1,
                                       mode='max')
# callback to save the Keras model and (best) weights obtained on an epoch basis. here, the trained (compiled) model is saved in the current working directory as 'cifar10.h5'
checkpoint = ModelCheckpoint(f'GoogleNet-modelv1-{datetime.datetime.now().__format__("%Y-%m-%d-%H-%M-%S")}.h5',
                                         monitor='val_loss',
                                         verbose=1,
                                         save_weights_only=False,
                                         save_best_only=True,
                                         mode='max',
                                         save_freq='epoch')

#Tensorboard
current_time = datetime.datetime.now().__format__('%Y-%m-%d-%H-%M-%S')
tb_callback = TensorBoard(log_dir=f"./logs/GoogleNetv1-modelv1-{current_time}", histogram_freq=2)

# %%
# Record the start time
start_time = time.time()

# Your existing code for model compilation and training
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

train_history = model.fit(
    train_set,
    batch_size=32,
    validation_data = val_set,
    # steps_per_epoch = EPOCH_STEPS,
    epochs=30,
    verbose =1,
    
    callbacks=[lr_reduce, checkpoint, tb_callback, early_stop]
)

# Record the end time
end_time = time.time()

# Calculate and print the total training time
total_time = end_time - start_time
print(f"Total training time: {total_time:.2f} seconds")
# Out:
# Epoch 1/30
# 58/58 [==============================] - ETA: 0s - loss: 4.6673 - main_loss: 1.6043 - aux1_loss: 1.5279 - aux2_loss: 1.5350 - main_accuracy: 0.2526 - aux1_accuracy: 0.3344 - aux2_accuracy: 0.2824
# Epoch 1: val_loss improved from -inf to 4.82404, saving model to GoogleNet-modelv1-2024-01-06-22-44-14.h5
# 58/58 [==============================] - 47s 614ms/step - loss: 4.6673 - main_loss: 1.6043 - aux1_loss: 1.5279 - aux2_loss: 1.5350 - main_accuracy: 0.2526 - aux1_accuracy: 0.3344 - aux2_accuracy: 0.2824 - val_loss: 4.8240 - val_main_loss: 1.6130 - val_aux1_loss: 1.6028 - val_aux2_loss: 1.6083 - val_main_accuracy: 0.2000 - val_aux1_accuracy: 0.2108 - val_aux2_accuracy: 0.2000 - lr: 0.0010
# Epoch 2/30
# 58/58 [==============================] - ETA: 0s - loss: 3.9227 - main_loss: 1.3693 - aux1_loss: 1.2484 - aux2_loss: 1.3050 - main_accuracy: 0.3995 - aux1_accuracy: 0.4645 - aux2_accuracy: 0.4385
# Epoch 2: val_loss did not improve from 4.82404
# 58/58 [==============================] - 17s 300ms/step - loss: 3.9227 - main_loss: 1.3693 - aux1_loss: 1.2484 - aux2_loss: 1.3050 - main_accuracy: 0.3995 - aux1_accuracy: 0.4645 - aux2_accuracy: 0.4385 - val_loss: 4.6626 - val_main_loss: 1.5300 - val_aux1_loss: 1.5884 - val_aux2_loss: 1.5442 - val_main_accuracy: 0.3656 - val_aux1_accuracy: 0.3183 - val_aux2_accuracy: 0.3247 - lr: 0.0010
# Epoch 3/30
# 58/58 [==============================] - ETA: 0s - loss: 3.4564 - main_loss: 1.2067 - aux1_loss: 1.0897 - aux2_loss: 1.1599 - main_accuracy: 0.4764 - aux1_accuracy: 0.5415 - aux2_accuracy: 0.4954
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
#
# Epoch 3: val_loss did not improve from 4.82404
# 58/58 [==============================] - 18s 317ms/step - loss: 3.4564 - main_loss: 1.2067 - aux1_loss: 1.0897 - aux2_loss: 1.1599 - main_accuracy: 0.4764 - aux1_accuracy: 0.5415 - aux2_accuracy: 0.4954 - val_loss: 4.7441 - val_main_loss: 1.4634 - val_aux1_loss: 1.7661 - val_aux2_loss: 1.5146 - val_main_accuracy: 0.2946 - val_aux1_accuracy: 0.2172 - val_aux2_accuracy: 0.2645 - lr: 0.0010
# Epoch 4/30
# 58/58 [==============================] - ETA: 0s - loss: 2.8897 - main_loss: 1.0182 - aux1_loss: 0.8949 - aux2_loss: 0.9767 - main_accuracy: 0.5398 - aux1_accuracy: 0.6537 - aux2_accuracy: 0.5772
# Epoch 4: val_loss improved from 4.82404 to 5.92832, saving model to GoogleNet-modelv1-2024-01-06-22-44-14.h5
# 58/58 [==============================] - 18s 309ms/step - loss: 2.8897 - main_loss: 1.0182 - aux1_loss: 0.8949 - aux2_loss: 0.9767 - main_accuracy: 0.5398 - aux1_accuracy: 0.6537 - aux2_accuracy: 0.5772 - val_loss: 5.9283 - val_main_loss: 2.0294 - val_aux1_loss: 1.7953 - val_aux2_loss: 2.1036 - val_main_accuracy: 0.3441 - val_aux1_accuracy: 0.3527 - val_aux2_accuracy: 0.3398 - lr: 6.0000e-04
# Epoch 5/30
# 58/58 [==============================] - ETA: 0s - loss: 2.5365 - main_loss: 0.8996 - aux1_loss: 0.7866 - aux2_loss: 0.8504 - main_accuracy: 0.6417 - aux1_accuracy: 0.6943 - aux2_accuracy: 0.6715
# Epoch 5: val_loss did not improve from 5.92832
# 58/58 [==============================] - 19s 321ms/step - loss: 2.5365 - main_loss: 0.8996 - aux1_loss: 0.7866 - aux2_loss: 0.8504 - main_accuracy: 0.6417 - aux1_accuracy: 0.6943 - aux2_accuracy: 0.6715 - val_loss: 4.8754 - val_main_loss: 1.6632 - val_aux1_loss: 1.5475 - val_aux2_loss: 1.6648 - val_main_accuracy: 0.4065 - val_aux1_accuracy: 0.3806 - val_aux2_accuracy: 0.4237 - lr: 6.0000e-04
# Epoch 6/30
# 58/58 [==============================] - ETA: 0s - loss: 2.3779 - main_loss: 0.8507 - aux1_loss: 0.7330 - aux2_loss: 0.7942 - main_accuracy: 0.6531 - aux1_accuracy: 0.7111 - aux2_accuracy: 0.6900
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
#
# Epoch 6: val_loss did not improve from 5.92832
# 58/58 [==============================] - 18s 305ms/step - loss: 2.3779 - main_loss: 0.8507 - aux1_loss: 0.7330 - aux2_loss: 0.7942 - main_accuracy: 0.6531 - aux1_accuracy: 0.7111 - aux2_accuracy: 0.6900 - val_loss: 4.2758 - val_main_loss: 1.4068 - val_aux1_loss: 1.4748 - val_aux2_loss: 1.3942 - val_main_accuracy: 0.4495 - val_aux1_accuracy: 0.4710 - val_aux2_accuracy: 0.4602 - lr: 6.0000e-04
# Epoch 7/30
# 58/58 [==============================] - ETA: 0s - loss: 2.0704 - main_loss: 0.7339 - aux1_loss: 0.6456 - aux2_loss: 0.6909 - main_accuracy: 0.7274 - aux1_accuracy: 0.7550 - aux2_accuracy: 0.7409
# Epoch 7: val_loss did not improve from 5.92832
# 58/58 [==============================] - 19s 322ms/step - loss: 2.0704 - main_loss: 0.7339 - aux1_loss: 0.6456 - aux2_loss: 0.6909 - main_accuracy: 0.7274 - aux1_accuracy: 0.7550 - aux2_accuracy: 0.7409 - val_loss: 3.9415 - val_main_loss: 1.3406 - val_aux1_loss: 1.2803 - val_aux2_loss: 1.3206 - val_main_accuracy: 0.4968 - val_aux1_accuracy: 0.5161 - val_aux2_accuracy: 0.5032 - lr: 3.6000e-04
# Epoch 8/30
# 58/58 [==============================] - ETA: 0s - loss: 1.8458 - main_loss: 0.6494 - aux1_loss: 0.5822 - aux2_loss: 0.6141 - main_accuracy: 0.7539 - aux1_accuracy: 0.7821 - aux2_accuracy: 0.7734
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
#
# Epoch 8: val_loss did not improve from 5.92832
# 58/58 [==============================] - 18s 306ms/step - loss: 1.8458 - main_loss: 0.6494 - aux1_loss: 0.5822 - aux2_loss: 0.6141 - main_accuracy: 0.7539 - aux1_accuracy: 0.7821 - aux2_accuracy: 0.7734 - val_loss: 3.0379 - val_main_loss: 1.0036 - val_aux1_loss: 1.0594 - val_aux2_loss: 0.9750 - val_main_accuracy: 0.5656 - val_aux1_accuracy: 0.5656 - val_aux2_accuracy: 0.5656 - lr: 3.6000e-04
# Epoch 9/30
# 58/58 [==============================] - ETA: 0s - loss: 1.6354 - main_loss: 0.5700 - aux1_loss: 0.5170 - aux2_loss: 0.5484 - main_accuracy: 0.7799 - aux1_accuracy: 0.7930 - aux2_accuracy: 0.7913
# Epoch 9: val_loss did not improve from 5.92832
# 58/58 [==============================] - 19s 333ms/step - loss: 1.6354 - main_loss: 0.5700 - aux1_loss: 0.5170 - aux2_loss: 0.5484 - main_accuracy: 0.7799 - aux1_accuracy: 0.7930 - aux2_accuracy: 0.7913 - val_loss: 1.8125 - val_main_loss: 0.6388 - val_aux1_loss: 0.5647 - val_aux2_loss: 0.6090 - val_main_accuracy: 0.7312 - val_aux1_accuracy: 0.7548 - val_aux2_accuracy: 0.7441 - lr: 2.1600e-04
# Epoch 9: early stopping
# Total training time: 194.12 seconds

# %%
import matplotlib.pyplot as plt

# Assuming you have the training history stored in the variable 'train_history'

# Plot the training loss
plt.plot(train_history.history['loss'], label='Training Loss')

# Plot the validation loss
plt.plot(train_history.history['val_loss'], label='Validation Loss')

plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have the training history stored in the variable 'train_history'

# Plot the training accuracy
plt.plot(train_history.history['main_accuracy'], label='Training Accuracy')

# Plot the validation accuracy
plt.plot(train_history.history['val_main_accuracy'], label='Validation Accuracy')

plt.title('Training and Validation Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have the true labels and predicted labels for the test set
true_labels = test_set.classes

# Ensure that model.predict returns a NumPy array
predicted_probs = model.predict(test_set)
if isinstance(predicted_probs, list):
    # Concatenate the predictions from multiple branches (assuming main branch is the first)
    predicted_probs = np.concatenate(predicted_probs, axis=1)

# Convert predicted probabilities to class indices
predicted_labels = predicted_probs.argmax(axis=1)

# Compute confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       4 import numpy as np
#       6 # Assuming you have the true labels and predicted labels for the test set
# ----> 7 true_labels = test_set.classes
#       9 # Ensure that model.predict returns a NumPy array
#      10 predicted_probs = model.predict(test_set)
#
# NameError: name 'test_set' is not defined

# %%
import matplotlib.pyplot as plt

# Display the first image in the batch
plt.imshow(images[0])
plt.show()

# %% [markdown]
# # Constraints

# %%
# Extract a batch of images from your dataset
images, _ = next(val_set)

# Measure inference time for making predictions
start_time = time.time()

# Assuming your model is named 'model' and you want predictions for the batch of images
predictions = model.predict(images)

end_time = time.time()

# Calculate and print the inference time
inference_time = end_time - start_time
print(f"Inference Time: {inference_time:.4f} seconds")
# Out:
# Inference Time: 0.3954 seconds

# %%
def get_model_size(model):
    # Save the model to a temporary file
    model.save('temp_model.h5')

    # Get the size of the saved model file
    model_size = os.path.getsize('temp_model.h5')

    # Remove the temporary file
    os.remove('temp_model.h5')

    return model_size

# Load your model
model = tf.keras.models.load_model(r'D:\New_Fourth_Year\projectDesignGit\sugarcaneSeverityLevel\GoogleNet-modelv1-2024-01-06-22-44-14.h5')

# Get the size of the model
model_size_bytes = get_model_size(model)

# Convert bytes to megabytes for better readability
model_size_megabytes = model_size_bytes / (1024 * 1024)

print(f"Model Size: {model_size_megabytes:.2f} MB")
# Out:
# Model Size: 85.51 MB

# %%
model = tf.keras.models.load_model(r'D:\New_Fourth_Year\projectDesignGit\sugarcaneSeverityLevel\GoogleNet-modelv1-2024-01-06-22-44-14.h5')
# Assuming you have a test set generator
test_set = val_set  # Define or load your test set generator

# Use model.evaluate to get accuracy and other metrics
results = model.evaluate(test_set, verbose=1)  # Set verbose=1 for more information

# 'results' is a list containing the evaluation metrics
accuracy = results[1]  # Index 1 corresponds to the accuracy

# Compute misclassification rate
misclassification_rate = 1 - accuracy

print(f'Misclassification Rate: {misclassification_rate * 100:.2f}%')
# Out:
# 15/15 [==============================] - 2s 130ms/step - loss: 5.9283 - main_loss: 2.0294 - aux1_loss: 1.7953 - aux2_loss: 2.1036 - main_accuracy: 0.3441 - aux1_accuracy: 0.3527 - aux2_accuracy: 0.3398
# Misclassification Rate: -102.94%

# %%
# 'results' is a list containing the evaluation metrics
main_accuracy = results[4]  # Index 4 corresponds to the accuracy of the main branch

print(f'Main Branch Accuracy: {main_accuracy:.2%}')
# Out:
# Main Branch Accuracy: 34.41%

# %%
from sklearn.metrics import accuracy_score

# Assuming you have the true labels and predicted labels for the test set
true_labels = test_set.classes

# Ensure that model.predict returns a NumPy array
predicted_probs = model.predict(test_set)
if isinstance(predicted_probs, list):
    # Concatenate the predictions from multiple branches (assuming main branch is the first)
    predicted_probs = np.concatenate(predicted_probs, axis=1)

# Convert predicted probabilities to class labels
predicted_labels = predicted_probs.argmax(axis=1)

# Compute accuracy using sklearn's accuracy_score
accuracy = accuracy_score(true_labels, predicted_labels)

# Compute misclassification rate
misclassification_rate = 1 - accuracy

print(f'Misclassification Rate: {misclassification_rate:.2%}')
# Out:
# 170/170 [==============================] - 6s 33ms/step
# Misclassification Rate: 96.31%

# %%
def get_flops(model_h5_path):
    session = tf.compat.v1.Session()
    graph = tf.compat.v1.get_default_graph()


    with graph.as_default():
        with session.as_default():
            model = tf.keras.models.load_model(model_h5_path)

            run_meta = tf.compat.v1.RunMetadata()
            opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()

            # We use the Keras session graph in the call to the profiler.
            flops = tf.compat.v1.profiler.profile(graph=graph,
                                                  run_meta=run_meta, cmd='op', options=opts)

            return flops.total_float_ops

# %%
model_h5_path = r'D:\New_Fourth_Year\projectDesignGit\sugarcaneSeverityLevel\GoogleNet-modelv1-2024-01-06-22-44-14.h5'
# Get and print the FLOPs
flops = get_flops(model_h5_path)
print(f"Number of FLOPs: {flops}")
# Out:
# WARNING:tensorflow:From c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\keras\layers\normalization\batch_normalization.py:532: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\Users\Jerico\anaconda3\envs\gpu\lib\site-packages\tensorflow\python\profiler\internal\flops_registry.py:138: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# Number of FLOPs: 7415059
